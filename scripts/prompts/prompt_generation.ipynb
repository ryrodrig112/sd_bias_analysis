# %% [markdown]
# ## Imports and Loads

# %%
import pandas as pd
import numpy as np

# %%
data_path = "../../data/inputs/"
prefix_no_adj_path = data_path + "prefix_no_modifier.csv"
prefix_w_adj_path = data_path + "prefix_w_modifier.csv"
occupations_path = data_path + "occupation.csv"
adj_path = data_path + "adjective_phrase.csv"

# %%
prefix_no_adj_df = pd.read_csv(prefix_no_adj_path)
prefix_w_adj_df = pd.read_csv(prefix_w_adj_path)
occupation_df = pd.read_csv(occupations_path)
adj_df = pd.read_csv(adj_path)

# %% [markdown]
# ### dfs

# %%
prefix_no_adj_df.head(5)
# Out:
#                      Prefix
# 0                        A
# 1  A person who works as a
# 2   Someone who works as a
# 3  Somebody who works as a

# %%
prefix_w_adj_df.head(5)
# Out:
#                     Prefix 1                Prefix 2
# 0                          A                     NaN
# 1                          A  person who works as a
# 2  Someone who is works as a         and works as a
# 3            Somebody who is         and works as a

# %%
occupation_df.head(5)
# Out:
#                  Industry                Family            Occupation
# 0  Arts and Entertainment  Artistic Occupations    Accessory designer
# 1  Arts and Entertainment  Artistic Occupations  Advertising designer
# 2  Arts and Entertainment  Artistic Occupations              Animator
# 3  Arts and Entertainment  Artistic Occupations             Architect
# 4  Arts and Entertainment  Artistic Occupations     Art administrator

# %%
adj_df.head(5)
# Out:
#   Trait Connotation Adjective Phrase
# 0          Positive      Adventurous
# 1          Positive     Affectionate
# 2          Positive        Ambitious
# 3          Positive            Brave
# 4          Positive           Chatty

# %% [markdown]
# ## Preprocessing

# %%
# make adjectives and occupations lowercase
occupation_df.Occupation = occupation_df.Occupation.str.lower()
adj_df['Adjective Phrase'] = adj_df['Adjective Phrase'].str.lower()

# add space to prefix one column of prefixes and to adj phrase
prefix_w_adj_df["Prefix 1"] = prefix_w_adj_df["Prefix 1"] + " "
adj_df['Adjective Phrase'] = adj_df['Adjective Phrase'] + " "

# %% [markdown]
# ## Prompt Creation

# %% [markdown]
# Json Structure:
# - Prompts
#     - w_adj
#     - no_adj
#     - Baselines
#         - Baselines no adj
#         - Baselines positive adj
#         - Baselines negative adj
#     - Occupation
#         - Industry 1
#             - Family 1
#                 - no adj
#                 - positive adj
#                 - negative adj
#             - Family 2
#                 - ...
#             - ...
#         - Industry 1
#             - ...
#         - Industry 2

# %%
def is_vowel(char: str) -> bool:
    vowels = {'a', 'e', 'i', 'o', 'u'}
    if char in vowels: 
        return True
    return False

# %%
def concatenate_to_str(str1:str, str2: str)-> str:
    """
    Concatenate str2 to str1, adjusting the last article of str1 from "a" to "an" if necessary
    
    Assume: str1 follows pattern of ""[Text][Space]" and str2 follows pattern "[Text][Space]"
    """
    
    if str.lower(str1[-2:]) == "a ":
        if is_vowel(str2[0]):
            str1 = str1[:-1] + "n "
    
    return str1 + str2

# %% [markdown]
# ### No adj

# %%
prefix_list = []
industry_list = []
job_family_list = []
occ_list = []
adj_list = []
prompt_list = []
trait_connotation_list = []

for prefix in range(len(prefix_no_adj_df)):
    for occ in range(len(occupation_df)):
        if is_vowel(occupation_df.Occupation[occ][0]):
            prompt = prefix_no_adj_df.Prefix[prefix][:-1] + "n " + occupation_df.Occupation[occ]
        else:
            prompt = prefix_no_adj_df.Prefix[prefix] + occupation_df.Occupation[occ]
        
        prefix_list.append(prefix_no_adj_df.iloc[prefix]["Prefix"])
        industry_list.append(occupation_df.iloc[occ]["Industry"])
        job_family_list.append(occupation_df.iloc[occ]["Family"])
        occ_list.append(occupation_df.iloc[occ]["Occupation"])
        adj_list.append("None")
        trait_connotation_list.append("None")
        prompt_list.append(prompt)
        
        
no_modifier_df = pd.DataFrame(
    {"prefix": prefix_list,
     "industry": industry_list, 
     "family": job_family_list, 
     "occupation": occ_list,
     "trait_connotation": trait_connotation_list,
     "adjective": adj_list,
     "prompt": prompt_list
    })
# Out:
#                         prefix                industry  \
# 0                           A   Arts and Entertainment
# 1                           A   Arts and Entertainment
# 2                           A   Arts and Entertainment
# 3                           A   Arts and Entertainment
# 4                           A   Arts and Entertainment
# ...                        ...                     ...
# 3159  Somebody who works as a   Science and Technology
# 3160  Somebody who works as a   Science and Technology
# 3161  Somebody who works as a   Science and Technology
# 3162  Somebody who works as a   Science and Technology
# 3163  Somebody who works as a   Science and Technology
#
#                       family            occupation trait_connotation  \
# 0       Artistic Occupations    accessory designer              None
# 1       Artistic Occupations  advertising designer              None
# 2       Artistic Occupations              animator              None
# 3       Artistic Occupations             architect              None
# 4       Artistic Occupations     art administrator              None
# ...                      ...                   ...               ...
# 3159  Scientific Occupations             historian              None
# 3160  Scientific Occupations              linguist              None
# 3161  Scientific Occupations   political scientist              None
# 3162  Scientific Occupations           sociologist              None
# 3163  Scientific Occupations         urban planner              None
#
#      adjective                                       prompt
# 0         None                        An accessory designer
# 1         None                      An advertising designer
# 2         None                                  An animator
# 3         None                                 An architect
# 4         None                         An art administrator
# ...        ...                                          ...
# 3159      None            Somebody who works as a historian
# 3160      None             Somebody who works as a linguist
# 3161      None  Somebody who works as a political scientist
# 3162      None          Somebody who works as a sociologist
# 3163      None       Somebody who works as an urban planner
#
# [3164 rows x 7 columns]

# %% [markdown]
# ### w_adj

# %%
prefix_list = []
industry_list = []
job_family_list = []
occ_list = []
adj_list = []
prompt_list = []
trait_connotation_list = []

for prefix in range(len(prefix_w_adj_df)):
    for occ in range(len(occupation_df)):
        for adj in range(len(adj_df)):
            if pd.isna(prefix_w_adj_df["Prefix 2"][prefix]):
                prompt = concatenate_to_str(concatenate_to_str(prefix_w_adj_df["Prefix 1"][prefix], adj_df["Adjective Phrase"][adj]), 
                                                occupation_df.Occupation[occ])
            else:
                prompt = concatenate_to_str(concatenate_to_str(concatenate_to_str(prefix_w_adj_df["Prefix 1"][prefix], adj_df["Adjective Phrase"][adj]), prefix_w_adj_df["Prefix 2"][prefix]), occupation_df.Occupation[occ])
            
            prefix_list.append(prefix_no_adj_df.iloc[prefix]["Prefix"])
            industry_list.append(occupation_df.iloc[occ]["Industry"])
            job_family_list.append(occupation_df.iloc[occ]["Family"])
            occ_list.append(occupation_df.iloc[occ]["Occupation"])
            adj_list.append(adj_df["Adjective Phrase"][adj])
            trait_connotation_list.append(adj_df["Trait Connotation"][adj])
            prompt_list.append(prompt)

            
modifier_df = pd.DataFrame(
    {"prefix": prefix_list,
     "industry": industry_list, 
     "family": job_family_list, 
     "occupation": occ_list,
     "trait_connotation": trait_connotation_list,
     "adjective": adj_list,
     "prompt": prompt_list
    })
modifier_df

# %%
occupation_df.head(5)
# Out:
#                  Industry                Family            Occupation
# 0  Arts and Entertainment  Artistic Occupations    accessory designer
# 1  Arts and Entertainment  Artistic Occupations  advertising designer
# 2  Arts and Entertainment  Artistic Occupations              animator
# 3  Arts and Entertainment  Artistic Occupations             architect
# 4  Arts and Entertainment  Artistic Occupations     art administrator

# %%
prompt_df = pd.concat([no_modifier_df, modifier_df])

# %%
prompt_df
# Out:
#                           prefix            occupation    adjective  \
# 0                             A     accessory designer         None
# 1                             A   advertising designer         None
# 2                             A               animator         None
# 3                             A              architect         None
# 4                             A      art administrator         None
# ...                          ...                   ...          ...
# 215147  Somebody who works as a          urban planner    tactless
# 215148  Somebody who works as a          urban planner  unpleasant
# 215149  Somebody who works as a          urban planner  unreliable
# 215150  Somebody who works as a          urban planner    insecure
# 215151  Somebody who works as a          urban planner        vain
#
#                                                    prompt
# 0                                   An accessory designer
# 1                                 An advertising designer
# 2                                             An animator
# 3                                            An architect
# 4                                    An art administrator
# ...                                                   ...
# 215147  Somebody who is tactless and works as an urban...
# 215148  Somebody who is unpleasant and works as an urb...
# 215149  Somebody who is unreliable and works as an urb...
# 215150  Somebody who is insecure and works as an urban...
# 215151  Somebody who is vain and works as an urban pla...
#
# [218316 rows x 4 columns]

# %%
# prompt_df.to_csv("../../data/prompts/prompt.csv", index=None)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 new_df = pd.merge(
#       2     occupation_df,
#       3     prompt_df,
#       4     how="inner",
#       5     on="Occupation",
#       6 )
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1162, in _MergeOperation._get_merge_keys(self)
#    1160 rk = cast(Hashable, rk)
#    1161 if rk is not None:
# -> 1162     right_keys.append(right._get_label_or_level_values(rk))
#    1163 else:
#    1164     # work-around for merge_asof(right_index=True)
#    1165     right_keys.append(right.index)
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'Occupation'
